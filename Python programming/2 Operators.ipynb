# %% [markdown]
# ### 1. Arithmetic Operators:

# %% [markdown]
# As in other languages, the standard arithmetic operators are addition (+), subtraction (-), multiplication (*), and
# division (/).
# <div>
#     <img src="attachment:image.png" width="600"/>
# </div>

# %%
x = 15
y = 4

# Output: x + y = 19
print('x + y =',x+y)

# Output: x - y = 11
print('x - y =',x-y)

# Output: x * y = 60
print('x * y =',x*y)

# Output: x / y = 3.75
print('x / y =',x/y)

# Output: x // y = 3
print('x // y =',x//y)

# Output: x ** y = 50625
print('x ** y =',x**y)
# Out:
# x + y = 19
# x - y = 11
# x * y = 60
# x / y = 3.75
# x // y = 3
# x ** y = 50625

# %% [markdown]
# The **operator precedence**
# in Python is listed in the following table. It is in descending order (upper group has higher precedence than the lower ones).
# <div>
#     <img src="attachment:image.png" width="600"/>
# </div>

# %%
u=1400
v=20
x=10
y=8
z=5

print (u/v + x + y*z)
# Out:
# 120.0

# %%
a,b,c = 4,4,4
print(a/2 +b/2 +c/2)
# Out:
# 6.0

# %%
# Left-right associativity
print(5 * 2 // 3)

# Shows left-right associativity
print(5 * (2 // 3))
# Out:
# 3
# 0

# %% [markdown]
# ### 2. Assignment operators
# Assignment operators are used in Python to assign values to variables.
#
# a = 5 is a simple assignment operator that assigns the value 5 on the right to the variable a on the left.
#
# There are various compound operators in Python like a += 5 that adds to the variable and later assigns the same. It is equivalent to a = a + 5.
# <div>
#     <img src=attachment:image.png width=400/>
# </div>

# %%
a=12
a += 1
a
# Out:
# 13

# %%
a/=2
a
# Out:
# 6.5

# %% [markdown]
# ### 3. Comparison(Relational) operators
# Comparison operators are used to compare values. It returns either True or False according to the condition.
# <div>
#     <img src="attachment:image.png" width="600"/>
# </div>

# %%
x = 10
y = 12

# Output: x > y is False
print('x > y is',x>y)

# Output: x < y is True
print('x < y is',x<y)

# Output: x == y is False
print('x == y is',x==y)

# Output: x != y is True
print('x != y is',x!=y)

# Output: x >= y is False
print('x >= y is',x>=y)

# Output: x <= y is True
print('x <= y is',x<=y)
# Out:
# x > y is False
# x < y is True
# x == y is False
# x != y is True
# x >= y is False
# x <= y is True

# %% [markdown]
# ### 4. Boolean Logical operators
# <div>
#     <img src="attachment:image.png" width="600"/>
# </div>

# %%
x = True
y = False

print('x and y is',x and y)

print('x or y is',x or y)

print('not x is',not x)
# Out:
# x and y is False
# x or y is True
# not x is False

# %% [markdown]
# ### 5. Bitwise operators
# Bitwise operators act on operands as if they were strings of binary digits. They operate bit by bit, hence the name.
#
#
# In the table below: Let x = 10 (0000 1010 in binary) and y = 4 (0000 0100 in binary)
# <div>
#     <img src="attachment:image.png" width="600"/>
#
# </div>

# %%
# example, 2 is 10 in binary and 7 is 111.
print("2 in binary is 10 : ", bin(2))
print("7 in binary is 111: ", bin(7))
# Out:
# 2 in binary is 10 :  0b10
# 7 in binary is 111:  0b111

# %%
x=10  #Binary of 10 is : 1010
y=4   #Binary of 4 is  : 0100

# %%
# Bitwise AND:
x&y

#Binary of 10 is : 1010
#Binary of 4 is  : 0100
#-----------------------
#Binary of 10&4  : 0000

#0000 is 0 in decimals
# Out:
# 0

# %%
#Bitwise OR:
x|y

#Binary of 10 is : 1010
#Binary of 4 is  : 0100
#-----------------------
#Binary of 10|4  : 1110

# 1110 is 14 in decimals
# Out:
# 14

# %% [markdown]
# ### Special operators
# #### 5.Membership operators
# #### 6.Identity operators

# %% [markdown]
# #### 5.Membership operators
# in and not in are the membership operators in Python. They are used to test whether a value or variable is found in a sequence (string, list, tuple, set and dictionary).
# <div>
#     <img src="attachment:image.png" width="600"/>
#
# </div>

# %%
x = 'Hello world'
print('H' in x)
# Out:
# True

# %%
print('sachin' not in x)
# Out:
# True

# %%
list1= [12,45,78,98]

78 in list1
# Out:
# True

# %% [markdown]
# #### 6.Identity operators
# is and is not are the identity operators in Python.
#
# They are used to check if two values (or variables) are located on the same part of the memory. Two variables that are equal does not imply that they are identical.
# <div>
#     <img src="attachment:image.png" width="600"/>
#
# </div>

# %%
x1 = 5
y1 = 5
x2 = 'Hello'
y2 = 'Hello'
x3 = [1,2,3]
y3 = [1,2,3]

print(x1 is y1) #x1 and y1 are integers of the same values, so they are equal as well as identical. 

print(x2 is y2) #same for strings also

# Output: False
print(x3 is y3) #But x3 and y3 are lists. They are equal but not identical. It is because the interpreter locates them separately in memory although they are equal.
# Out:
# True
# True
# False

# %%
x3==y3
# Out:
# True

# %% [markdown]
# # The End
# ***
