# %% [markdown]
# # List:
# ![image.png](attachment:image.png)

# %%
l= [11, 2.3, "sachin", 67, 89]

# %%
type(l)
# Out:
# list

# %%
cars =["Audi","Mercedes","Ford","Royals Royce","Tata","BMW",'Hyundai',"Honda","Porshe"]

# %%
cars[2]
# Out:
# 'Ford'

# %%
print("I own a "+cars[6]+" car")
# Out:
# I own a Hyundai car

# %%
cars[2]="Maruti"  #List is Mutable(Changable)

# %%
print(cars)
# Out:
# ['Audi', 'Mercedes', 'Maruti', 'Royals Royce', 'Tata', 'BMW', 'Hyundai', 'Honda', 'Porshe']

# %% [markdown]
# #### append at the end in the List:

# %%
cars.append("mahindra")

# %%
print(cars)
# Out:
# ['Audi', 'Mercedes', 'Maruti', 'Royals Royce', 'Tata', 'BMW', 'Hyundai', 'Honda', 'Porshe', 'mahindra']

# %% [markdown]
# #### insert an item at a position:

# %%
cars.insert(3,"ferrari")

# %%
print(cars)
# Out:
# ['Audi', 'Mercedes', 'Maruti', 'ferrari', 'Royals Royce', 'Tata', 'BMW', 'Hyundai', 'Honda', 'Porshe', 'mahindra']

# %%
cars.append("ferrari")

# %%
print(cars)
# Out:
# ['Audi', 'Mercedes', 'Maruti', 'ferrari', 'Royals Royce', 'Tata', 'BMW', 'Hyundai', 'Honda', 'Porshe', 'mahindra', 'ferrari']

# %% [markdown]
# ### slicing:

# %%
print(cars[  2 :   ])
# Out:
# ['Maruti', 'ferrari', 'Royals Royce', 'Tata', 'BMW', 'Hyundai', 'Honda', 'Porshe', 'mahindra', 'ferrari']

# %%
print(cars[  :  : 2])
# Out:
# ['Audi', 'Maruti', 'Royals Royce', 'BMW', 'Honda', 'mahindra']

# %%
print(cars[  :  : -1])
# Out:
# ['ferrari', 'mahindra', 'Porshe', 'Honda', 'Hyundai', 'BMW', 'Tata', 'Royals Royce', 'ferrari', 'Maruti', 'Mercedes', 'Audi']

# %%
cars =['Mercedes','Audi','Maruti','ferrari','Royals Royce','Tata','BMW','Hyundai','Honda','Porshe','mahindra']

# %% [markdown]
# ### Delete an item by its index :

# %%
del cars[2]

# %% [markdown]
# #### Remove an item by its name(value):

# %%
cars.remove('Tata')

# %%
print(cars)
# Out:
# ['Audi', 'Mercedes', 'Maruti', 'ferrari', 'Royals Royce', 'Tata', 'BMW', 'Hyundai', 'Honda', 'Porshe', 'mahindra']

# %%
cars.pop()
# Out:
# 'mahindra'

# %%
cars
# Out:
# ['Audi',
#  'Maruti',
#  'ferrari',
#  'Royals Royce',
#  'Tata',
#  'BMW',
#  'Hyundai',
#  'Honda',
#  'Porshe']

# %% [markdown]
# ## some more methosd of List:

# %%
cars =['Mercedes','Audi','Maruti','ferrari','Royals Royce','Tata','BMW','Hyundai','Honda','Porshe','mahindra']

cars.sort()

print(cars)
# Out:
# ['Audi', 'BMW', 'Honda', 'Hyundai', 'Maruti', 'Mercedes', 'Porshe', 'Royals Royce', 'Tata', 'ferrari', 'mahindra']

# %%
cars =['Mercedes','Audi','Maruti','ferrari','Royals Royce','Tata','BMW','Hyundai','Honda','Porshe','mahindra']

cars.sort(reverse=True)

print(cars)
# Out:
# ['mahindra', 'ferrari', 'Tata', 'Royals Royce', 'Porshe', 'Mercedes', 'Maruti', 'Hyundai', 'Honda', 'BMW', 'Audi']

# %%
cars =['Mercedes','Audi','Maruti','ferrari','Royals Royce','Tata','BMW','Hyundai','Honda','Porshe','mahindra']

cars.reverse()

print(cars)
# Out:
# ['mahindra', 'Porshe', 'Honda', 'Hyundai', 'BMW', 'Tata', 'Royals Royce', 'ferrari', 'Maruti', 'Audi', 'Mercedes']

# %% [markdown]
# ### Temperorily Sorting:

# %%
cars =['Mercedes','Audi','Maruti','ferrari','Royals Royce','Tata','BMW','Hyundai','Honda','Porshe','mahindra']

sorted(cars)

# %%
print(cars)
# Out:
# ['Mercedes', 'Audi', 'Maruti', 'ferrari', 'Royals Royce', 'Tata', 'BMW', 'Hyundai', 'Honda', 'Porshe', 'mahindra']

# %% [markdown]
# ### Length of the List:

# %%
len(cars)
# Out:
# 11

# %% [markdown]
# ### String to List:

# %%
list("aditya nagdiya")
# Out:
# ['a', 'd', 'i', 't', 'y', 'a', ' ', 'n', 'a', 'g', 'd', 'i', 'y', 'a']

# %%
"sachin sourabh rahul virat".split()
# Out:
# ['sachin', 'sourabh', 'rahul', 'virat']

# %%
"sachin,sourabh,rahul,virat".split() # default splitter is " ", which will not work here for the seperation of each word
# Out:
# ['sachin,sourabh,rahul,virat']

# %%
"sachin,sourabh,rahul,virat".split(",")
# Out:
# ['sachin', 'sourabh', 'rahul', 'virat']

# %%
"sachin:sourabh:rahul:virat".split(":")
# Out:
# ['sachin', 'sourabh', 'rahul', 'virat']

# %%
s= input("enter ur friends name: ")

friends = s.split()

print(f"\nHello {friends[0].title()}, come to my party !!!")
print(f"Hello {friends[1].title()}, come to my party !!!")
print(f"Hello {friends[2].title()}, come to my party !!!")
# Out:
# enter ur friends name: aseem rahul himanshu
#
# Hello Aseem, come to my party !!!
# Hello Rahul, come to my party !!!
# Hello Himanshu, come to my party !!!

# %%
l1=[12,45,12,55]

# %%
l2=[2,435,612,855]

# %%
l1+l2
# Out:
# [12, 45, 12, 55, 2, 435, 612, 855]

# %% [markdown]
# # Tuple:
# ![image.png](attachment:image.png)

# %%
t= (12,23.4,"aditya")

# %%
type(t)
# Out:
# tuple

# %%
t[1]=233 #Tuples are immutable (unchangable)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-176-de5c51c17b1e> in <module>
# ----> 1 t[1]=233 #Tuples are immutable (unchangable)
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple([23,65,12])
# Out:
# (23, 65, 12)

# %%
t[0]
# Out:
# 12

# %%
t[::-1]
# Out:
# ('aditya', 23.4, 12)

# %%
t1=(12,234,1,34)

# %%
sorted(t)
# Out:
# [1, 12, 34, 234]

# %%
t
# Out:
# (12, 234, 1, 34, 12, 234, 1, 34)

# %%
t2=(122,34,13,34,34)

# %%
t2
# Out:
# (122, 34, 13, 34, 34)

# %%
t3 =t1+t2

# %%
t3
# Out:
# (12, 234, 1, 34, 122, 34, 13, 34)

# %%
tuple('aditya nagdiya')
# Out:
# ('a', 'd', 'i', 't', 'y', 'a', ' ', 'n', 'a', 'g', 'd', 'i', 'y', 'a')

# %% [markdown]
# ## set:

# %%
s={12,56,87,12}

# %%
s
# Out:
# {12, 56, 87}

# %%
type(s)
# Out:
# set

# %%
set([38,55,23,45,55,23])
# Out:
# {23, 38, 45, 55}

# %%
set_DA={'aditya','agi','shiva','blesson'}

# %%
set_ML={'aalind','umar','shiva','blesson','rohan','neha','saket'}

# %%
set_DA.intersection(set_ML)
#or
#set_DA & set_ML
# Out:
# {'blesson', 'shiva'}

# %%
#set_DA.union(set_ML)
# or
# set_ML.union(set_DA)
set_DA | set_ML
# Out:
# {'aalind',
#  'aditya',
#  'agi',
#  'blesson',
#  'neha',
#  'rohan',
#  'saket',
#  'shiva',
#  'umar'}

# %%
set('aditya nagdiya')
# Out:
# {' ', 'a', 'd', 'g', 'i', 'n', 't', 'y'}

# %% [markdown]
# ### Dictionary:
# ![image.png](attachment:image.png)

# %%
d ={1:'aditya',3:'shiva',6:'saket'}

# %%
type(d)
# Out:
# dict

# %%
d.items()
# Out:
# dict_items([(1, 'aditya'), (3, 'shiva'), (6, 'saket')])

# %%
d.keys()
# Out:
# dict_keys([1, 3, 6])

# %%
d.values()
# Out:
# dict_values(['aditya', 'shiva', 'saket'])

# %%
d[1]
# Out:
# 'aditya'

# %%
d ={1:'aditya','urkey2':'shiva',15:'saket'}

# %%
d['urkey2']
# Out:
# 'shiva'

# %%
d ={1:'aditya', 2:'shiva', 15:'saket', 2:78}

# %%
d[2]
# Out:
# 78
